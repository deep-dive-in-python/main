# %% [markdown]
# # 6. 텍스트

# %%
import matplotlib.pyplot as plt

import matplotlib
matplotlib.rcParams['font.family'] = 'HYGungSo-Bold' #Windows일때
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False #한글폰트 사용시 마이너스 글자 꺠지는 현상 없앤다

# %%
x = [1,2,3]
y = [2,4,8]

# %%
plt.plot(x,y) #각 데이터가 어떤 값인지 모른다

# %%
plt.plot(x,y, marker='o')

for idx, txt in enumerate(y) :
    plt.text(x[idx], y[idx]+0.2, txt, ha='center', color='blue') #ha : 수평정렬
