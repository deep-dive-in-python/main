# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. 그래프 기본

# %%
x = [1,2,3]
y = [2,4,8]
plt.plot(x, y)

# %%
print(plt.plot(x,y)) #아래의 text를 보기 싫으면 plt.show() 만 하면된다.

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Title 설정

# %%
plt.plot(x,y)
plt.title('LIne graph')
# Out:
# Text(0.5, 1.0, 'LIne graph')

# %%
plt.plot(x,y)
plt.title('꺾은선 그래프') #한글을 쓰기위한 환경설정 필요
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
# C:\Users\sarah\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sarah\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sarah\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sarah\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\sarah\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
# ...

# %% [markdown]
# # 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'HYGungSo-Bold' #Windows일때
matplotlib.rcParams['font.size'] = 15

# %%
#폰트에 관한 정보 얻고싶을 때
import matplotlib.font_manager as fm
fm.fontManager.ttflist #사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist] #폰트 이름부분만 확인하기
# Out:
# ['cmex10',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Sans Display',
#  'cmsy10',
#  'STIXSizeTwoSym',
#  'cmss10',
#  'STIXNonUnicode',
#  'cmb10',
#  'cmtt10',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif Display',
#  'STIXNonUnicode',
#  'cmmi10',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'STIXSizeTwoSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXSizeFiveSym',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'cmr10',
#  'DejaVu Sans',
#  'STIXSizeFourSym',
#  'DejaVu Serif',
#  'STIXSizeOneSym',
#  'Lucida Sans Unicode',
#  'Cambria',
#  'Georgia',
#  'Candara',
#  'Consolas',
#  'Microsoft JhengHei',
#  'Bodoni MT',
#  'NanumSquareRound',
#  'Bahnschrift',
#  'Microsoft Tai Le',
#  'Calibri',
#  'Calisto MT',
#  'HCR Batang',
#  'Copperplate Gothic Bold',
# ...

# %%
plt.plot(x,y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot([-1,0,1],[-5,-1,2]) #음수 데이터는 표시가 안된다. 환경설정 필요

import matplotlib
matplotlib.rcParams['font.family'] = 'HYGungSo-Bold' #Windows일때
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False #한글폰트 사용시 마이너스 글자 꺠지는 현상 없앤다
