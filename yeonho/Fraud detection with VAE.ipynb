# %% [markdown]
# ### Fraud Detection with Variational Autoencoder

# %% [markdown]
# In my previous naive attempt at applying autoencoders to fraud detection, I trained a simple autoencoder with one hidden layer on each of the encoder side and decoder side. The autoencoder was asymmetrical and overcomplete, i.e. the hidden layer dimensions and the latent dimension were asymetrical and larger than the input size. Even so, it seemed to perform alright by piping the latent encoding through a simple linear classifer. An adversarial net was also tried out, but only as a classifier alternative to the linear benchmark. This may be something I would revisit in the future.
#
# In this new attempt, using the same credit card data by ULB machine learning group, I explore applying Variational Autoencoders (VAE) to the same problem. Functionally, Variational Autoencoders also try to reconstruct the input, but with the additional contraint that the latent representation learns the probability distribution parameters of the input rather than an arbitrary encoding of the input, hance the "Variational". What's good about learning the distribution? One, by explicitly modeling the data and noise generation processes, VAE can learn to separate the two, making it more robust. Two, the latent space can become more interpreble if disentanglement constraints are applied. Three, you can generate new samples by sampling latent vectors and pipe them through the decoder. There are more points and I will leave the technical details to the true professionals. You can find the resources that helped me below.

# %% [markdown]
# ### Contents
# 1. Raw Dataset
# 2. Visualize Preprocessed Transaction Features
# 3. Train a Variational Autoencoder
# 4. Visualize Latent Representations
# 5. VAE vs SVM
# 6. Evaluation on Test Set
# 7. Limitations

# %%
import numpy as np

# %%
# !pip install --upgrade --pre tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\sarah\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: setuptools in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (63.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (3.6.0)
# Collecting flatbuffers<2,>=1.12
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: packaging in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sarah\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.33.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.27.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sarah\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-nightly 2.10.0.dev20220721 requires flatbuffers>=2.0, but you have flatbuffers 1.12 which is incompatible.
# tf-nightly-gpu 2.10.0.dev20220721 requires flatbuffers>=2.0, but you have flatbuffers 1.12 which is incompatible.
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sarah\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Installing collected packages: flatbuffers
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
# Successfully installed flatbuffers-2.0

# %%
# !pip install --upgrade --pre tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Using cached tensorflow_gpu-2.9.1-cp39-cp39-win_amd64.whl (444.0 MB)
# Collecting flatbuffers<2,>=1.12
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (0.26.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (1.21.5)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (14.0.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (3.19.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: setuptools in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (63.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (2.9.0)
# Requirement already satisfied: packaging in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (4.1.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (3.6.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (2.9.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (1.42.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-gpu) (2.9.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sarah\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (2.27.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (1.33.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (3.3.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sarah\anaconda3\lib\site-packages (from packaging->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (2022.6.15)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sarah\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow-gpu) (3.2.0)
# Installing collected packages: flatbuffers, tensorflow-gpu
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
# Successfully installed flatbuffers-1.12 tensorflow-gpu-2.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-nightly 2.10.0.dev20220721 requires flatbuffers>=2.0, but you have flatbuffers 1.12 which is incompatible.
# tf-nightly-gpu 2.10.0.dev20220721 requires flatbuffers>=2.0, but you have flatbuffers 1.12 which is incompatible.

# %%
# !pip install --upgrade tf-nightly  --user
# !pip install --upgrade tf-nightly-gpu
# Out:
# Requirement already satisfied: tf-nightly in c:\users\sarah\appdata\roaming\python\python39\site-packages (2.10.0.dev20220721)
# Collecting tf-nightly
#   Downloading tf_nightly-2.10.0.dev20220724-cp39-cp39-win_amd64.whl (362.0 MB)
#      -------------------------------------- 362.0/362.0 MB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.42.0)
# Requirement already satisfied: tf-estimator-nightly~=2.10.0.dev in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (2.10.0.dev2022072208)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (4.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (0.26.0)
# Requirement already satisfied: setuptools in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (63.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (14.0.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (3.19.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.1.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (3.6.0)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.21.5)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.1.0)
# Requirement already satisfied: tb-nightly~=2.10.0.a in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (2.10.0a20220721)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (3.3.0)
# Requirement already satisfied: keras-nightly~=2.10.0.dev in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (2.10.0.dev2022072207)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (0.4.0)
# Requirement already satisfied: packaging in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (21.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sarah\anaconda3\lib\site-packages (from astunparse>=1.6.0->tf-nightly) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (3.3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (1.33.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (0.4.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sarah\anaconda3\lib\site-packages (from packaging->tf-nightly) (3.0.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.10.0.a->tf-nightly) (1.3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sarah\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.10.0.a->tf-nightly) (3.2.0)
# Installing collected packages: flatbuffers, tf-nightly
#   Attempting uninstall: tf-nightly
#     Found existing installation: tf-nightly 2.10.0.dev20220721
#     Uninstalling tf-nightly-2.10.0.dev20220721:
#       Successfully uninstalled tf-nightly-2.10.0.dev20220721
#   WARNING: The scripts estimator_ckpt_converter.exe, import_pb_to_tensorboard.exe, saved_model_cli.exe, tf_upgrade_v2.exe, tflite_convert.exe, toco.exe and toco_from_protos.exe are installed in 'C:\Users\sarah\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\sarah\\AppData\\Roaming\\Python\\Python39\\site-packages\\~ensorflow\\compiler\\tf2tensorrt\\_pywrap_py_utils.pyd'
# Check the permissions.
# Requirement already satisfied: tf-nightly-gpu in c:\users\sarah\appdata\roaming\python\python39\site-packages (2.10.0.dev20220721)
# Collecting tf-nightly-gpu
#   Downloading tf_nightly_gpu-2.10.0.dev20220724-cp39-cp39-win_amd64.whl (362.0 MB)
#      -------------------------------------- 362.0/362.0 MB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (14.0.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.6.3)
# Requirement already satisfied: tf-estimator-nightly~=2.10.0.dev in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (2.10.0.dev2022072208)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (3.6.0)
# Requirement already satisfied: tb-nightly~=2.10.0.a in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (2.10.0a20220721)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.1.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.12.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\sarah\appdata\roaming\python\python39\site-packages (from tf-nightly-gpu) (2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (0.26.0)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# Requirement already satisfied: keras-nightly~=2.10.0.dev in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (2.10.0.dev2022072207)
# Requirement already satisfied: setuptools in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (63.2.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.21.5)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (3.19.1)
# Requirement already satisfied: packaging in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (21.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.42.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (4.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sarah\anaconda3\lib\site-packages (from astunparse>=1.6.0->tf-nightly-gpu) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly-gpu) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly-gpu) (1.33.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly-gpu) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly-gpu) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly-gpu) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly-gpu) (2.0.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly-gpu) (2.27.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sarah\anaconda3\lib\site-packages (from packaging->tf-nightly-gpu) (3.0.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly-gpu) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly-gpu) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly-gpu) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.10.0.a->tf-nightly-gpu) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly-gpu) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly-gpu) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly-gpu) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly-gpu) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sarah\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.10.0.a->tf-nightly-gpu) (3.2.0)
# Installing collected packages: tf-nightly-gpu
#   Attempting uninstall: tf-nightly-gpu
#     Found existing installation: tf-nightly-gpu 2.10.0.dev20220721
#     Uninstalling tf-nightly-gpu-2.10.0.dev20220721:
#       Successfully uninstalled tf-nightly-gpu-2.10.0.dev20220721
# Successfully installed tf-nightly-gpu-2.10.0.dev20220724

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# %%
import tensorflow as tf
from tensorflow.python import tf2
if not tf2.enabled():
    import tensorflow.compat.v2 as tf
    tf.enable_v2_behavior()
    assert tf2.enabled()

# %%
# !pip3 install --upgrade tensorflow-probability
# Out:
# Requirement already satisfied: tensorflow-probability in c:\users\sarah\anaconda3\lib\site-packages (0.17.0)
# Requirement already satisfied: decorator in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (5.1.1)
# Requirement already satisfied: dm-tree in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (0.1.7)
# Requirement already satisfied: gast>=0.3.2 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (0.4.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (1.21.5)
# Requirement already satisfied: absl-py in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (1.16.0)
# Requirement already satisfied: cloudpickle>=1.3 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (2.0.0)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.1.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# alembic                       1.8.1
# anaconda-client               1.9.0
# anaconda-navigator            2.2.0
# anaconda-project              0.10.2
# anyio                         3.5.0
# Note: you may need to restart the kernel to use updated packages.appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# bitarray                      2.4.1
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# bkcharts                      0.2
# black                         19.10b0
# bleach                        4.1.0
# blis                          0.7.8
# bokeh                         2.4.2
# boto3                         1.21.32
# botocore                      1.24.32
# Bottleneck                    1.3.4
# brotlipy                      0.7.0
# bw2python                     0.6.1
# cachetools                    4.2.2
# catalogue                     2.0.7
# catboost                      1.0.6
# certifi                       2022.6.15
# cffi                          1.15.0
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# cloudpickle                   2.0.0
# clyent                        1.2.2
# colorama                      0.4.4
# colorcet                      2.0.6
# colorlover                    0.3.0
# comtypes                      1.1.10
# concat                        0.1.2.dev1
# conda                         4.13.0
# conda-build                   3.21.8
# conda-content-trust           0+unknown
# conda-pack                    0.6.0
# conda-package-handling        1.8.1
# conda-repo-cli                1.0.4
# conda-token                   0.3.0
# conda-verify                  3.4.2
# constantly                    15.1.0
# cookiecutter                  1.7.3
# cryptography                  3.4.8
# cssselect                     1.1.0
# cufflinks                     0.17.3
# cycler                        0.11.0
# cymem                         2.0.6
# Cython                        0.29.28
# cytoolz                       0.11.0
# daal4py                       2021.5.0
# dask                          2022.2.1
# databricks-cli                0.17.0
# datashader                    0.13.0
# datashape                     0.5.4
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# Delorean                      1.0.0
# diff-match-patch              20200713
# distributed                   2022.2.1
# dm-tree                       0.1.7
# docker                        5.0.3
# docutils                      0.17.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# fastjsonschema                2.15.1
# filelock                      3.6.0
# flake8                        3.9.2
# Flask                         1.1.2
# flatbuffers                   2.0
# fonttools                     4.25.0
# frozenlist                    1.2.0
# fsspec                        2022.2.0
# funcy                         1.17
# future                        0.18.2
# gast                          0.4.0
# gensim                        4.1.2
# gitdb                         4.0.9
# GitPython                     3.1.27
# glob2                         0.7
# google-api-core               1.25.1
# google-auth                   1.33.0
# google-auth-oauthlib          0.4.6
# google-cloud-core             1.7.1
# google-cloud-storage          1.31.0
# google-crc32c                 1.1.2
# google-pasta                  0.2.0
# google-resumable-media        1.3.1
# googleapis-common-protos      1.53.0
# graphviz                      0.20
# greenlet                      1.1.1
# grpcio                        1.42.0
# h5py                          3.6.0
# HeapDict                      1.0.1
# holoviews                     1.14.8
# htmlmin                       0.1.12
# humanize                      4.2.3
# hvplot                        0.7.3
# hyperlink                     21.0.0
# idna                          3.3
# imagecodecs                   2021.8.26
# ImageHash                     4.2.1
# imageio                       2.9.0
# imagesize                     1.3.0
# imbalanced-learn              0.9.1
# importlib-metadata            4.11.3
# incremental                   21.3.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.5
# intervaltree                  3.1.0
# ipykernel                     6.9.1
# ipython                       8.2.0
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jdcal                         1.4.1
# jedi                          0.18.1
# Jinja2                        2.11.3
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.1.0
# json5                         0.9.6
# jsonschema                    4.4.0
# jupyter                       1.0.0
# jupyter-client                6.1.12
# jupyter-console               6.4.0
# jupyter-core                  4.9.2
# jupyter-server                1.13.5
# jupyterlab                    3.3.2
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.10.3
# jupyterlab-widgets            1.0.0
# keras                         2.9.0
# keras-nightly                 2.10.0.dev2022072207
# Keras-Preprocessing           1.1.2
# keyring                       23.4.0
# kiwisolver                    1.3.2
# kmodes                        0.12.1
# langcodes                     3.3.0
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# libclang                      14.0.1
# lightgbm                      3.3.2
# llvmlite                      0.38.0
# locket                        0.2.1
# lxml                          4.8.0
# Mako                          1.2.1
# Markdown                      3.3.4
# MarkupSafe                    2.1.1
# matplotlib                    3.5.1
# matplotlib-inline             0.1.2
# mccabe                        0.6.1
# menuinst                      1.4.18
# missingno                     0.5.1
# mistune                       0.8.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# mlflow                        1.27.0
# mlxtend                       0.20.0
# mock                          4.0.3
# mpmath                        1.2.1
# msgpack                       1.0.2
# msgpack-python                0.5.6
# multidict                     5.1.0
# multimethod                   1.8
# multipledispatch              0.6.0
# munkres                       1.1.4
# murmurhash                    1.0.7
# mypy-extensions               0.4.3
# navigator-updater             0.2.1
# nbclassic                     0.3.5
# nbclient                      0.5.13
# nbconvert                     6.4.4
# nbformat                      5.3.0
# nest-asyncio                  1.5.5
# network                       0.1
# networkx                      2.7.1
# nltk                          3.7
# nose                          1.3.7
# notebook                      6.4.8
# numba                         0.55.1
# numexpr                       2.8.1
# numpy                         1.21.5
# numpydoc                      1.2
# oauthlib                      3.2.0
# olefile                       0.46
# openpyxl                      3.0.9
# opt-einsum                    3.3.0
# packaging                     21.3
# pandas                        1.4.2
# pandas-profiling              3.2.0
# pandocfilters                 1.5.0
# panel                         0.13.0
# param                         1.12.0
# paramiko                      2.8.1
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.2.0
# pathspec                      0.7.0
# pathy                         0.6.2
# patsy                         0.5.2
# pep8                          1.7.1
# pexpect                       4.8.0
# phik                          0.12.2
# pickleshare                   0.7.5
# Pillow                        9.0.1
# pip                           22.2
# pkginfo                       1.8.2
# plotly                        5.6.0
# pluggy                        1.0.0
# ply                           3.11
# poyo                          0.5.0
# preshed                       3.0.6
# prometheus-client             0.13.1
# prometheus-flask-exporter     0.20.2
# prompt-toolkit                3.0.20
# Protego                       0.1.16
# protobuf                      3.19.1
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py                            1.11.0
# pyasn1                        0.4.8

# %%
# !pip3 install tensorflow-probability
# Out:
# pyasn1-modules                0.2.8
# pycapnp                       1.1.1
# pycaret                       2.2.2
# pycodestyle                   2.7.0
# pycosat                       0.6.3
# pycparser                     2.21
# pyct                          0.4.6
# pycurl                        7.44.1
# pydantic                      1.9.1
# PyDispatcher                  2.0.5
# pydocstyle                    6.1.1
# pyerfa                        2.0.0
# pyflakes                      2.3.1
# Pygments                      2.11.2
# PyHamcrest                    2.0.2
# PyJWT                         2.1.0
# pyLDAvis                      3.3.1
# pylint                        2.9.6
# pyls-spyder                   0.4.0
# PyNaCl                        1.4.0
# pynndescent                   0.5.7
# pyod                          1.0.3
# pyodbc                        4.0.32
# pyOpenSSL                     21.0.0
# pyparsing                     3.0.4
# pyreadline                    2.1
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pytest                        7.1.1
# python-dateutil               2.8.2
# python-lsp-black              1.0.0
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.2.4
# python-slugify                5.0.2
# python-snappy                 0.6.0
# python-utils                  3.3.3
# pytz                          2021.3
# pytz-deprecation-shim         0.1.0.post0
# pyviz-comms                   2.0.2
# PyWavelets                    1.3.0
# pywin32                       227
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.2
# PyYAML                        6.0
# pyzmq                         22.3.0
# QDarkStyle                    3.0.2
# qstylizer                     0.1.10
# QtAwesome                     1.0.3
# qtconsole                     5.3.0
# QtPy                          2.0.1
# querystring-parser            1.2.4
# queuelib                      1.5.0
# regex                         2022.3.15
# requests                      2.27.1
# requests-file                 1.5.1
# requests-oauthlib             1.3.1
# rope                          0.22.0
# rsa                           4.7.2
# Rtree                         0.9.7
# ruamel-yaml-conda             0.15.100
# s3transfer                    0.5.0
# scikit-image                  0.19.2
# scikit-learn                  1.1.1
# scikit-learn-intelex          2021.20220215.102710
# scikit-plot                   0.3.7
# scipy                         1.7.3
# Scrapy                        2.6.1
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    63.2.0
# sip                           4.19.13
# six                           1.16.0
# sklearn                       0.0
# smart-open                    5.2.1
# smmap                         5.0.0
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcollections             2.1.0
# sortedcontainers              2.4.0
# soupsieve                     2.3.1
# spacy                         3.4.0
# spacy-legacy                  3.0.9
# spacy-loggers                 1.0.3
# Sphinx                        4.4.0
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.1.5
# spyder-kernels                2.1.3
# SQLAlchemy                    1.4.32
# sqlparse                      0.4.2
# srsly                         2.4.3
# stack-data                    0.2.0
# statsmodels                   0.13.2
# sympy                         1.10.1
# tables                        3.6.1
# tabulate                      0.8.9
# tangled-up-in-unicode         0.2.0
# tb-nightly                    2.10.0a20220721
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.0.1
# tensorboard                   2.9.1
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.9.1
# tensorflow-estimator          2.9.0
# tensorflow-gpu                2.9.1
# tensorflow-io-gcs-filesystem  0.26.0
# tensorflow-probability        0.17.0
# termcolor                     1.1.0
# terminado                     0.13.1
# testpath                      0.5.0
# text-unidecode                1.3
# textblob                      0.17.1
# textdistance                  4.2.1
# tf-estimator-nightly          2.10.0.dev2022072208
# tf-nightly                    2.10.0.dev20220724
# tf-nightly-gpu                2.10.0.dev20220724
# tfp-nightly                   0.7.0.dev20190312
# thinc                         8.1.0
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2021.7.2
# tinycss                       0.4
# tldextract                    3.2.0
# toml                          0.10.2
# tomli                         1.2.2
# toolz                         0.11.2
# torch                         1.12.0
# torchvision                   0.13.0
# tornado                       6.1
# tqdm                          4.64.0
# traitlets                     5.1.1
# Twisted                       22.2.0
# twisted-iocpsupport           1.0.2
# typed-ast                     1.4.3
# typer                         0.4.2
# typing_extensions             4.1.1
# tzdata                        2022.1
# tzlocal                       4.2
# ujson                         5.1.0
# umap-learn                    0.5.3
# Unidecode                     1.2.0
# urllib3                       1.26.9
# visions                       0.7.4
# w3lib                         1.21.0
# waitress                      2.1.2
# wasabi                        0.9.1
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.0.3
# wheel                         0.37.1
# widgetsnbextension            3.5.2
# win-inet-pton                 1.1.0
# win-unicode-console           0.5
# wincertstore                  0.2
# wordcloud                     1.8.2.2
# wrapt                         1.12.1
# xarray                        0.20.1
# xbos                          0.0.35
# xgboost                       1.6.1
# xlrd                          2.0.1
# XlsxWriter                    3.0.3
# xlwings                       0.24.9
# yapf                          0.31.0
# yarl                          1.6.3
# yellowbrick                   1.4
# zict                          2.0.0
# zipp                          3.7.0
# zope.interface                5.4.0
# Requirement already satisfied: tensorflow-probability in c:\users\sarah\anaconda3\lib\site-packages (0.17.0)
# Requirement already satisfied: cloudpickle>=1.3 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (2.0.0)
# Requirement already satisfied: absl-py in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (1.16.0)
# Requirement already satisfied: gast>=0.3.2 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (0.4.0)
# Requirement already satisfied: dm-tree in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (0.1.7)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (1.21.5)
# Requirement already satisfied: decorator in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (5.1.1)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)

# %%
# !pip install --upgrade tf-nightly 
# !pip install --upgrade tf-nightly-gpu
# Out:
# Requirement already satisfied: tf-nightly in c:\users\sarah\appdata\roaming\python\python39\site-packages (2.10.0.dev20220724)
# Requirement already satisfied: six>=1.12.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.16.0)
# Requirement already satisfied: tb-nightly~=2.10.0.a in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (2.10.0a20220721)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.42.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.21.5)
# Requirement already satisfied: tf-estimator-nightly~=2.10.0.dev in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (2.10.0.dev2022072208)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.1.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (0.4.0)
# Requirement already satisfied: setuptools in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (63.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (4.1.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\sarah\appdata\roaming\python\python39\site-packages (from tf-nightly) (2.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.1.0)
# Requirement already satisfied: packaging in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (21.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (0.26.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (3.6.0)
# Requirement already satisfied: keras-nightly~=2.10.0.dev in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (2.10.0.dev2022072207)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (14.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.12.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (1.1.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly) (3.19.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sarah\anaconda3\lib\site-packages (from astunparse>=1.6.0->tf-nightly) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (2.27.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (1.33.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (3.3.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sarah\anaconda3\lib\site-packages (from packaging->tf-nightly) (3.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.10.0.a->tf-nightly) (1.3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sarah\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.10.0.a->tf-nightly) (3.2.0)
# Requirement already satisfied: tf-nightly-gpu in c:\users\sarah\anaconda3\lib\site-packages (2.10.0.dev20220724)
# Requirement already satisfied: six>=1.12.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.16.0)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.42.0)
# Requirement already satisfied: setuptools in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (63.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (0.2.0)
# Requirement already satisfied: tb-nightly~=2.10.0.a in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (2.10.0a20220721)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (4.1.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\sarah\appdata\roaming\python\python39\site-packages (from tf-nightly-gpu) (2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.1.0)
# Requirement already satisfied: tf-estimator-nightly~=2.10.0.dev in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (2.10.0.dev2022072208)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (14.0.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (3.19.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.21.5)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (0.4.0)
# Requirement already satisfied: keras-nightly~=2.10.0.dev in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (2.10.0.dev2022072207)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (0.26.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (3.6.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (1.1.2)
# Requirement already satisfied: packaging in c:\users\sarah\anaconda3\lib\site-packages (from tf-nightly-gpu) (21.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sarah\anaconda3\lib\site-packages (from astunparse>=1.6.0->tf-nightly-gpu) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly-gpu) (1.33.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly-gpu) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly-gpu) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly-gpu) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly-gpu) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly-gpu) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sarah\anaconda3\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly-gpu) (2.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sarah\anaconda3\lib\site-packages (from packaging->tf-nightly-gpu) (3.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly-gpu) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly-gpu) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly-gpu) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.10.0.a->tf-nightly-gpu) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly-gpu) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly-gpu) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly-gpu) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly-gpu) (1.26.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sarah\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.10.0.a->tf-nightly-gpu) (3.2.0)

# %%
# !pip install --user tensorflow --upgrade
# Out:
# Requirement already satisfied: tensorflow in c:\users\sarah\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: packaging in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Collecting flatbuffers<2,>=1.12
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: setuptools in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (63.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sarah\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.33.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-nightly 2.10.0.dev20220724 requires flatbuffers>=2.0, but you have flatbuffers 1.12 which is incompatible.
# tf-nightly-gpu 2.10.0.dev20220724 requires flatbuffers>=2.0, but you have flatbuffers 1.12 which is incompatible.
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.27.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sarah\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sarah\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sarah\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2022.6.15)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sarah\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sarah\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Installing collected packages: flatbuffers
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
# Successfully installed flatbuffers-1.12

# %%
# !pip install --user tensorflow-probability --upgrade
# Out:
# Requirement already satisfied: tensorflow-probability in c:\users\sarah\anaconda3\lib\site-packages (0.17.0)
# Requirement already satisfied: decorator in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (5.1.1)
# Requirement already satisfied: absl-py in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (1.21.5)
# Requirement already satisfied: gast>=0.3.2 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (0.4.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (1.16.0)
# Requirement already satisfied: cloudpickle>=1.3 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (2.0.0)
# Requirement already satisfied: dm-tree in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (0.1.7)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)

# %%
# !pip install --upgrade tensorflow-probability
# Out:
# Requirement already satisfied: tensorflow-probability in c:\users\sarah\anaconda3\lib\site-packages (0.17.0)
# Requirement already satisfied: dm-tree in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (0.1.7)
# Requirement already satisfied: absl-py in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (1.1.0)
# Requirement already satisfied: cloudpickle>=1.3 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (2.0.0)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# Requirement already satisfied: six>=1.10.0 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (1.16.0)
# Requirement already satisfied: gast>=0.3.2 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (0.4.0)
# Requirement already satisfied: decorator in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (5.1.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\sarah\anaconda3\lib\site-packages (from tensorflow-probability) (1.21.5)

# %%
import tensorflow_probability as tfp

# %%
tfk = tf.keras
tfkl = tf.keras.layers
tfpl = tfp.layers
tfd = tfp.distributions

# %%
from tensorflow.keras.utils import plot_model

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score, roc_curve
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE
import os

# %%
# %matplotlib inline
np.random.seed(0)
tf.random.set_seed(0)
print(tf.__version__)
print(tfp.__version__)
# Out:
# 2.10.0-dev20220724
# 0.17.0

# %%
### Utility Functions
## Plots
# Plot Feature Projection [credit: https://www.kaggle.com/shivamb/semi-supervised-classification-using-autoencoders]
def tsne_plot(x1, y1, name="graph.png"):
    tsne = TSNE(n_components=2, random_state=0)
    X_t = tsne.fit_transform(x1)
#     plt.figure(figsize=(12, 8))
    plt.scatter(X_t[np.where(y1 == 0), 0], X_t[np.where(y1 == 0), 1], marker='o', color='g', linewidth='1', alpha=0.8, label='Non Fraud', s=2)
    plt.scatter(X_t[np.where(y1 == 1), 0], X_t[np.where(y1 == 1), 1], marker='o', color='r', linewidth='1', alpha=0.8, label='Fraud', s=2)

    plt.legend(loc='best');
    plt.savefig(name);
    plt.show();
    
# Plot Keras training history
def plot_loss(hist):
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.yscale('log',basey=10)
    plt.show()

# %% [markdown]
# ### 1. Raw Dataset

# %%
td = pd.read_csv('C:/Users/sarah/Desktop/github/open/train.csv')
td['Class'] = 0

# %%
td.head()
# Out:
#    ID        V1        V2        V3        V4        V5        V6        V7  \
# 0   3 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 1   4 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 2   6 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 3   8 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 4   9 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 1  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 2  0.260314 -0.568671  ... -0.559825 -0.026398 -0.371427 -0.232794  0.105915
# 3 -3.807864  0.615375  ... -1.015455  0.057504 -0.649709 -0.415267 -0.051634
# 4  0.851084 -0.392048  ... -0.268092 -0.204233  1.011592  0.373205 -0.384157
#
#         V27       V28       V29       V30  Class
# 0 -0.055353 -0.059752  4.983721 -0.994972      0
# 1  0.062723  0.061458  1.418291 -0.994972      0
# 2  0.253844  0.081080 -0.256131 -0.994960      0
# 3 -1.206921 -1.085339  0.262698 -0.994901      0
# 4  0.011747  0.142404  0.994900 -0.994901      0
#
# [5 rows x 32 columns]

# %%
td.shape
# Out:
# (113842, 32)

# %%
non_fraud = td[td['Class'] == 0].sample(1000)
fraud = td[td['Class'] == 1]

df = non_fraud.append(fraud).sample(frac=1).reset_index(drop=True)
X = df.drop(['Class'], axis = 1).values
Y = df["Class"].values
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_31164\3837308552.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = non_fraud.append(fraud).sample(frac=1).reset_index(drop=True)

# %%
# !pip install pydot
# Out:
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\sarah\anaconda3\lib\site-packages (from pydot) (3.0.4)
# Installing collected packages: pydot
# Successfully installed pydot-1.4.2
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\users\sarah\appdata\roaming\python\python39\site-packages)

# %% [markdown]
# ### 3. Train a Variational Autoencoder 여기서부터 해보자

# %%
def dense_layers(sizes):
    return tfk.Sequential([tfkl.Dense(size, activation=tf.nn.leaky_relu) for size in sizes])

original_dim = X.shape[1]
input_shape = X[0].shape
intermediary_dims = [20, 10, 8]
latent_dim = 2
batch_size = 128
max_epochs = 1000

# prior = tfd.Independent(tfd.Normal(loc=tf.zeros(latent_dim), scale=1),
#                         reinterpreted_batch_ndims=1)

prior = tfd.MultivariateNormalDiag(
        loc=tf.zeros([latent_dim]),
        scale_identity_multiplier=1.0)

encoder = tfk.Sequential([
    tfkl.InputLayer(input_shape=input_shape, name='encoder_input'),
    dense_layers(intermediary_dims),
    tfkl.Dense(tfpl.MultivariateNormalTriL.params_size(latent_dim), activation=None),
    tfpl.MultivariateNormalTriL(latent_dim, 
                           activity_regularizer=tfpl.KLDivergenceRegularizer(prior)),
], name='encoder')

encoder.summary()
plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)

decoder = tfk.Sequential([
    tfkl.InputLayer(input_shape=[latent_dim]),
    dense_layers(reversed(intermediary_dims)),
    tfkl.Dense(tfpl.IndependentNormal.params_size(original_dim), activation=None),
    tfpl.IndependentNormal(original_dim),
], name='decoder')

decoder.summary()
plot_model(decoder, to_file='vae_mlp_decoder.png', show_shapes=True)

vae = tfk.Model(inputs=encoder.inputs,
                outputs=decoder(encoder.outputs[0]),
                name='vae_mlp')

negloglik = lambda x, rv_x: -rv_x.log_prob(x)

vae.compile(optimizer=tf.keras.optimizers.Nadam(), 
            loss=negloglik)

vae.summary()
plot_model(vae,
           to_file='vae_mlp.png',
           show_shapes=True)
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_2 (Sequential)   (None, 8)                 938
#
#  dense_11 (Dense)            (None, 5)                 45
#
#  multivariate_normal_tri_l_1  ((None, 2),              0
#   (MultivariateNormalTriL)    (None, 2))
#
# =================================================================
# Total params: 983
# Trainable params: 983
# Non-trainable params: 0
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_3 (Sequential)   (None, 20)                334
#
#  dense_15 (Dense)            (None, 62)                1302
#
#  independent_normal_1 (Indep  ((None, 31),             0
#  endentNormal)                (None, 31))
#
# =================================================================
# Total params: 1,636
# Trainable params: 1,636
# Non-trainable params: 0
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=tfp.distributions._TensorCoercible("tensor_coercible", batch_shape=[?], event_shape=[2], dtype=float32). Consider rewriting this model with the Functional API.
# Model: "vae_mlp"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 31)]              0
#
#  sequential_2 (Sequential)   (None, 8)                 938
#
#  dense_11 (Dense)            (None, 5)                 45
#
#  multivariate_normal_tri_l_1  ((None, 2),              0
#   (MultivariateNormalTriL)    (None, 2))
#
#  decoder (Sequential)        (None, 31)                1636
#
# =================================================================
# Total params: 2,619
# Trainable params: 2,619
# Non-trainable params: 0
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
x = td.drop(["Class"], axis=1)
y = td["Class"].values

x_norm, x_fraud = x.values[y == 0], x.values[y == 1]

x_norm_sample = x_norm[np.random.randint(x_norm.shape[0], size=100000), :]
x_norm_train_sample, x_norm_val_sample = train_test_split(x_norm_sample, test_size=0.2)

# %%
tf_train = tf.data.Dataset.from_tensor_slices((x_norm_train_sample, x_norm_train_sample)).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE).shuffle(int(10e4))
tf_val = tf.data.Dataset.from_tensor_slices((x_norm_val_sample, x_norm_val_sample)).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE).shuffle(int(10e4))

# %%
checkpointer = ModelCheckpoint(filepath='bestmodel.h5', verbose=0, save_best_only=True)
earlystopper = EarlyStopping(monitor='val_loss', mode='min', min_delta=0.005, patience=20, verbose=0, restore_best_weights=True)

hist = vae.fit(tf_train,
               epochs=max_epochs,
               shuffle=True,
               verbose=0,
               validation_data=tf_val,
               callbacks=[checkpointer, earlystopper])

plot_loss(hist)
# Out:
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=tfp.distributions._TensorCoercible("tensor_coercible", batch_shape=[?], event_shape=[2], dtype=float32). Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=tfp.distributions._TensorCoercible("tensor_coercible", batch_shape=[?], event_shape=[2], dtype=float32). Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=tfp.distributions._TensorCoercible("tensor_coercible", batch_shape=[?], event_shape=[2], dtype=float32). Consider rewriting this model with the Functional API.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 11>()
#       2 earlystopper = EarlyStopping(monitor='val_loss', mode='min', min_delta=0.005, patience=20, verbose=0, restore_best_weights=True)
#       4 hist = vae.fit(tf_train,
#       5                epochs=max_epochs,
#       6                shuffle=True,
#       7                verbose=0,
#       8                validation_data=tf_val,
#       9                callbacks=[checkpointer, earlystopper])
# ---> 11 plot_loss(hist)
#
# Input In [19], in plot_loss(hist)
#      21 plt.xlabel('epoch')
#      22 plt.legend(['train', 'test'], loc='upper left')
# ---> 23 plt.yscale('log',basey=10)
#      24 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:3055, in yscale(value, **kwargs)
#    3053 @_copy_docstring_and_deprecators(Axes.set_yscale)
#    3054 def yscale(value, **kwargs):
# -> 3055     return gca().set_yscale(value, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:4108, in _AxesBase.set_yscale(self, value, **kwargs)
#    4106 g = self.get_shared_y_axes()
#    4107 for ax in g.get_siblings(self):
# -> 4108     ax.yaxis._set_scale(value, **kwargs)
#    4109     ax._update_transScale()
#    4110     ax.stale = True
#
# File ~\anaconda3\lib\site-packages\matplotlib\axis.py:761, in Axis._set_scale(self, value, **kwargs)
#     759 def _set_scale(self, value, **kwargs):
#     760     if not isinstance(value, mscale.ScaleBase):
# --> 761         self._scale = mscale.scale_factory(value, self, **kwargs)
#     762     else:
#     763         self._scale = value
#
# File ~\anaconda3\lib\site-packages\matplotlib\scale.py:597, in scale_factory(scale, axis, **kwargs)
#     595     scale = scale.lower()
#     596 scale_cls = _api.check_getitem(_scale_mapping, scale=scale)
# --> 597 return scale_cls(axis, **kwargs)
#
# TypeError: __init__() got an unexpected keyword argument 'basey'

# %%
reconstruct_samples_n = 100

def reconstruction_log_prob(eval_samples, reconstruct_samples_n):
    encoder_out = encoder(eval_samples)
    encoder_samples = encoder_out.sample(reconstruct_samples_n)
    return np.mean(decoder(encoder_samples).log_prob(eval_samples), axis=0)

# %%
x_test_log_prob = reconstruction_log_prob(data_test.drop(['Class'], axis = 1).values, reconstruct_samples_n)
test_y = data_test["Class"].values

fpr, tpr, thresh = roc_curve(test_y, -x_test_log_prob)
auc = roc_auc_score(test_y, -x_test_log_prob)

plt.plot(fpr,tpr,label="linear in-sample, auc="+str(auc))
plt.title('VAE roc curve - test')
plt.ylabel('True Positive Rate')
plt.xlabel("False Positive Rate")
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 x_test_log_prob = reconstruction_log_prob(data_test.drop(['Class'], axis = 1).values, reconstruct_samples_n)
#       2 test_y = data_test["Class"].values
#       4 fpr, tpr, thresh = roc_curve(test_y, -x_test_log_prob)
#
# NameError: name 'reconstruction_log_prob' is not defined
